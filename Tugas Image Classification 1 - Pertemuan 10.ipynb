# %% [markdown]
# <a href="https://colab.research.google.com/github/agann2911/Pemrograman_Python/blob/main/Tugas%20Image%20Classification%201%20-%20Pertemuan%2010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
ls

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths
import numpy as np
import os

# %%
# grab all image paths in the input dataset directory, then initialize
# our list of images and corresponding class labels
print("[INFO] loading images...")
imagePaths = paths.list_images("3scene")
data = []
labels = []
# Out:
# [INFO] loading images...

# %%
# loop over our input images
for imagePath in imagePaths:
	# load the input image from disk, resize it to 64x64 pixels, scale
	# the pixel intensities to the range [0, 1], and then update our
	# images list
	image = Image.open(imagePath)
	image = np.array(image.resize((128, 128))) / 255.0
	data.append(image)

	# extract the class label from the file path and update the
	# labels list
	label = imagePath.split(os.path.sep)[-2]
	labels.append(label)

# %%
print(labels)

# %%
# encode the labels, converting them from strings to integers
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
print(labels)

# %%
# perform a training and testing split, using 75% of the data for
# training and 25% for evaluation
(trainX, testX, trainY, testY) = train_test_split(np.array(data),	np.array(labels), test_size=0.25)
print(trainX.shape)
print(testX.shape)
# Out:
# (711, 128, 128, 3)
# (237, 128, 128, 3)

# %%
from keras.applications.mobilenet import MobileNet
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Model
from keras.layers import GlobalAveragePooling2D, BatchNormalization

# %%
from keras.layers import Dropout
base_model = MobileNet(weights='imagenet', include_top=False)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
x = Dense(512, activation='relu')(x)
out = Dense(3, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=out)
model.summary()

# %%
es = EarlyStopping(monitor='val_loss',
                   patience=5,
                   mode='auto',
                   restore_best_weights=True)
checkpoint = ModelCheckpoint('best_weight_scene_mobileNet.h5',
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='auto',)

# %%
from keras.models import Sequential
from keras.layers.core import Flatten
from keras.layers.core import Dense

model = Sequential(
    [
        Flatten(input_shape=(128*128*3,)),
        Dense(100, activation="relu", name="layer1"),
        Dense(16, activation="relu", name="layer2"),
        Dense(16, activation="relu", name="layer3"),
        Dense(3, activation = "softmax", name="layer4"),
    ]
)

# %%
model.summary()

# %%
# train the model using the Adam optimizer
print("[INFO] training network...")
opt = Adam(lr=1e-3, decay=1e-3 / 50)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=50, batch_size=32, callbacks=[es, checkpoint])
# Out:
# [INFO] training network...
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 49152) for input Tensor("flatten_13_input:0", shape=(None, 49152), dtype=float32), but it was called on an input with incompatible shape (None, 128, 128, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 49152) for input Tensor("flatten_13_input:0", shape=(None, 49152), dtype=float32), but it was called on an input with incompatible shape (None, 128, 128, 3).
# 23/23 [==============================] - ETA: 0s - loss: 1.4446 - accuracy: 0.6006WARNING:tensorflow:Model was constructed with shape (None, 49152) for input Tensor("flatten_13_input:0", shape=(None, 49152), dtype=float32), but it was called on an input with incompatible shape (None, 128, 128, 3).
#
# Epoch 00001: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 46ms/step - loss: 1.4446 - accuracy: 0.6006 - val_loss: 0.8316 - val_accuracy: 0.5781
# Epoch 2/50
# 23/23 [==============================] - ETA: 0s - loss: 0.6308 - accuracy: 0.6934
# Epoch 00002: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 40ms/step - loss: 0.6308 - accuracy: 0.6934 - val_loss: 0.7765 - val_accuracy: 0.6835
# Epoch 3/50
# 23/23 [==============================] - ETA: 0s - loss: 0.4840 - accuracy: 0.8298
# Epoch 00003: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 40ms/step - loss: 0.4840 - accuracy: 0.8298 - val_loss: 0.7191 - val_accuracy: 0.7215
# Epoch 4/50
# 22/23 [===========================>..] - ETA: 0s - loss: 0.5289 - accuracy: 0.7798
# Epoch 00004: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 40ms/step - loss: 0.5329 - accuracy: 0.7778 - val_loss: 0.8175 - val_accuracy: 0.6540
# Epoch 5/50
# 23/23 [==============================] - ETA: 0s - loss: 0.5342 - accuracy: 0.7820
# Epoch 00005: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 40ms/step - loss: 0.5342 - accuracy: 0.7820 - val_loss: 0.7809 - val_accuracy: 0.6962
# Epoch 6/50
# 23/23 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.8397
# Epoch 00006: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 39ms/step - loss: 0.4246 - accuracy: 0.8397 - val_loss: 0.9376 - val_accuracy: 0.6160
# Epoch 7/50
# 23/23 [==============================] - ETA: 0s - loss: 0.8193 - accuracy: 0.6821
# Epoch 00007: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 40ms/step - loss: 0.8193 - accuracy: 0.6821 - val_loss: 0.8002 - val_accuracy: 0.7215
# Epoch 8/50
# 23/23 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.8481
# Epoch 00008: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 40ms/step - loss: 0.3972 - accuracy: 0.8481 - val_loss: 0.6954 - val_accuracy: 0.7342
# Epoch 9/50
# 23/23 [==============================] - ETA: 0s - loss: 0.3432 - accuracy: 0.8748
# Epoch 00009: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 39ms/step - loss: 0.3432 - accuracy: 0.8748 - val_loss: 0.6988 - val_accuracy: 0.7595
# Epoch 10/50
# 23/23 [==============================] - ETA: 0s - loss: 0.3623 - accuracy: 0.8819
# Epoch 00010: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 40ms/step - loss: 0.3623 - accuracy: 0.8819 - val_loss: 0.6650 - val_accuracy: 0.7384
# Epoch 11/50
# 23/23 [==============================] - ETA: 0s - loss: 0.3154 - accuracy: 0.8875
# Epoch 00011: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 39ms/step - loss: 0.3154 - accuracy: 0.8875 - val_loss: 0.6410 - val_accuracy: 0.7764
# Epoch 12/50
# 23/23 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.9156
# Epoch 00012: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 39ms/step - loss: 0.2842 - accuracy: 0.9156 - val_loss: 0.7127 - val_accuracy: 0.7426
# Epoch 13/50
# 23/23 [==============================] - ETA: 0s - loss: 0.2654 - accuracy: 0.9156
# Epoch 00013: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 39ms/step - loss: 0.2654 - accuracy: 0.9156 - val_loss: 1.0479 - val_accuracy: 0.6034
# Epoch 14/50
# 23/23 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.8833
# Epoch 00014: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 40ms/step - loss: 0.3161 - accuracy: 0.8833 - val_loss: 1.0212 - val_accuracy: 0.6160
# Epoch 15/50
# 23/23 [==============================] - ETA: 0s - loss: 0.5721 - accuracy: 0.7792
# Epoch 00015: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 40ms/step - loss: 0.5721 - accuracy: 0.7792 - val_loss: 0.7243 - val_accuracy: 0.7722
# Epoch 16/50
# 23/23 [==============================] - ETA: 0s - loss: 0.4317 - accuracy: 0.8256
# Epoch 00016: val_accuracy did not improve from 0.79747
# 23/23 [==============================] - 1s 39ms/step - loss: 0.4317 - accuracy: 0.8256 - val_loss: 0.7232 - val_accuracy: 0.7595

# %%
import matplotlib.pyplot as plt

print(H.history.keys())
# summarize history for accuracy
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# [INFO] evaluating network...
# WARNING:tensorflow:Model was constructed with shape (None, 49152) for input Tensor("flatten_13_input:0", shape=(None, 49152), dtype=float32), but it was called on an input with incompatible shape (None, 128, 128, 3).
#               precision    recall  f1-score   support
#
#        coast       0.74      0.83      0.78        92
#       forest       0.86      0.75      0.80        81
#      highway       0.75      0.73      0.74        64
#
#     accuracy                           0.78       237
#    macro avg       0.78      0.77      0.77       237
# weighted avg       0.78      0.78      0.78       237

# %%
model.save('nnmodel_scene')
# Out:
# INFO:tensorflow:Assets written to: nnmodel_scene/assets

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
ImageFile = 'test/ngetes.jpg'
print(ImageFile)
# Out:
# test/ngetes.jpg

# %%
img = Image.open(ImageFile)
plt.imshow(img)
plt.show()

# %%
image_testing = Image.open(ImageFile)
image_testing = np.array(image_testing.resize((128, 128))) / 255.0
image_testing.shape
# Out:
# (128, 128, 3)

# %%
image_testing = np.expand_dims(image_testing, axis=0)
print(image_testing.shape)
# Out:
# (1, 128, 128, 3)

# %%
output = model.predict(image_testing, 1)
print(output)
print(lb.classes_[output.argmax(axis=1)])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 49152) for input Tensor("flatten_13_input:0", shape=(None, 49152), dtype=float32), but it was called on an input with incompatible shape (1, 128, 128, 3).
# [[0.01124207 0.98638123 0.00237674]]
# ['forest']
